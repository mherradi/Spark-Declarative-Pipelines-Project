# %% [markdown]
# # 🚖 Good Cabs Data Platform Modernization

# %% [markdown]
# %md
# ### The main Project Catalog Creation
#
# This section initializes the primary catalog for the bike lakehouse project, which will organize schemas and tables for data management.

# %%
spark.sql('CREATE CATALOG IF NOT EXISTS transporation')
# Out:
# DataFrame[]

# %% [markdown]
# %md
# ### Create needed Schemas
#
# This section sets up the schemas within the bike_lakehouse catalog to organize data into bronze, silver, and gold layers.

# %%
spark.sql('CREATE SCHEMA IF NOT EXISTS transporation.bronze')
spark.sql('CREATE SCHEMA IF NOT EXISTS transporation.silver')
spark.sql('CREATE SCHEMA IF NOT EXISTS transporation.gold')
# Out:
# DataFrame[]
